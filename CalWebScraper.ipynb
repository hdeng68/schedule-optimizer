# %%
from urllib.request import urlopen
import re
from bs4 import BeautifulSoup
import json
import time

#below is an example of how to scrape a specific instance
'''
course_list = BeautifulSoup(urlopen("http://classes.berkeley.edu/search/site?page=311&f%5B0%5D=im_field_term_name%3A789").read())
print(course_list)

course_titles = course_list.findAll("div", {"class":"handlebarData theme_is_cc_berkeley"})
print(len(course_titles))

sample_json = course_titles[0].attrs['data-json']
print(course_titles[0].attrs['data-json'])
jsoned = json.loads(sample_json)
print(jsoned['course']['displayName'])

for c in course_titles:
    print(c.attrs['data-enrollment'])
    print(c.attrs['data-json'])
    print(c.attrs['data-term-details'])
    print(c.attrs['data-node'])
    print(c.attrs.keys())
'''
    
#below is the actual scraping code
#something messed up on page 171
i=171
while i < 311:
    url = "http://classes.berkeley.edu/search/site?page="+str(i+1)+"&f%5B0%5D=im_field_term_name%3A789"
    current_site = BeautifulSoup(urlopen(url).read())
    all_course_info = current_site.findAll("div", {"class":"handlebarData theme_is_cc_berkeley"})
    for c in all_course_info:
        course_json = c.attrs['data-json']
        parsed_json = json.loads(course_json)
        try:
            f = open("course_info/"+parsed_json['course']['displayName'].replace("/","")+".txt", "w+")
        except KeyError:
            f = open("course_info/"+parsed_json['class']['course']['displayName'].replace("/","")+'.txt', "w+")
        f.write(course_json)
        f.close()
    time.sleep(0.1)
    print(i)
    i+=1
# Out:
# /Users/kevinzhang/Documents/CS/schedule_optimizer/py/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# ...

# %%
# Out:
# <html><head></head><body></body></html>
# /Users/kevinzhang/Documents/CS/schedule_optimizer/py/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
